# %% [markdown]
# # Кибериммунная автономность$\\$Создание конструктивно защищённого автономного наземного транспортного средства$\\$Модуль 4
#
# ## О документе
#
# Версия 1.03
#
# Модуль 4 для регионального этапа соревнований по кибериммунной автономности

# %% [markdown]
# ### Модуль 4. Следование по трассе с киберпрепятствиями
#
# Для успешного выполнения этого задания необходимое активировать специальный режим работы виртуальной машинки - в рамках этого задания можно менять только блоки, отвечающие за безопасность (ограничитель, монитор безопасности), **другие блоки менять запрещено**.
#
# При прохождении маршрута будут имитироваться атаки со стороны злоумышленников, которые будут пытаться нарушить цели безопасности. Важно, чтобы им это не удалось.

# %% [markdown]
# 1. Запустите свою машинку и убедитесь, что она проходит всю трассу без нарушений ограничений скорости. При необходимости измените логику работы блока безопасности
# 2. Добавьте контроль доставки груза в модуле SafetyBlock - убедитесь, что груз доставляется до конечной точки маршрута.
# 3. Если в модуле 3 вы реализовали монитор безопасности - не забудьте его перенести в этот модуль, это принесёт дополнительные баллы!

# %% [markdown]
# Активация киберпрепятствий в системе управления:
#
# после инициализации системы управления добавьте следующую строку
# ```python
# control_system.enable_surprises()
# ```

# %% [markdown]
# В этом блоке добавьте все ваши реализации изменённых бортовых систем

# %%
from src.config import (
    CONTROL_SYSTEM_QUEUE_NAME, 
    SAFETY_BLOCK_QUEUE_NAME,
    SERVOS_QUEUE_NAME,
    CARGO_BAY_QUEUE_NAME,
    LOG_ERROR, 
    LOG_INFO,
    SECURITY_MONITOR_QUEUE_NAME
)
from src.event_types import Event
from src.queues_dir import QueuesDirectory
from queue import Queue
from src.control_system import BaseControlSystem
from src.navigation_system import BaseNavigationSystem
from src.communication_gateway import BaseCommunicationGateway
from src.safety_block import BaseSafetyBlock
from src.security_monitory import BaseSecurityMonitor
from src.security_policy_type import SecurityPolicy
from src.config import (
    COMMUNICATION_GATEWAY_QUEUE_NAME, 
    CONTROL_SYSTEM_QUEUE_NAME, 
    NAVIGATION_QUEUE_NAME,
    SAFETY_BLOCK_QUEUE_NAME,
    SERVOS_QUEUE_NAME,
    CARGO_BAY_QUEUE_NAME,
    LOG_DEBUG, 
    LOG_ERROR, 
    LOG_INFO
)
from src.event_types import Event
from src.queues_dir import QueuesDirectory
from queue import Queue
import math
from src.queues_dir import QueuesDirectory
from src.security_policy_type import SecurityPolicy

from src.config import COMMUNICATION_GATEWAY_QUEUE_NAME, LOG_DEBUG, LOG_ERROR, LOG_INFO

# ============================================================================
# ОГРАНИЧИТЕЛЬ (SAFETY BLOCK)
# ============================================================================

class SafetyBlock(BaseSafetyBlock):
    """ 
    Класс ограничителя безопасности
    
    Обеспечивает:
    - ЦБ1: соблюдение ограничений скорости и направления
    - ЦБ3: контроль доставки груза только в конечной точке маршрута
    """
    
    def _set_new_direction(self, direction: float):
        """ 
        Установка нового направления перемещения с проверкой безопасности
        
        Проверяет, что запрошенное направление соответствует расчетному
        направлению к следующей точке маршрута
        """
        self._log_message(LOG_INFO, f"текущие координаты: {self._position}")
        self._log_message(LOG_DEBUG, f"маршрутное задание: {self._mission}")
        self._log_message(LOG_DEBUG, f"состояние маршрута: {self._route}")
        
        # Если маршрут завершен, устанавливаем направление 0
        if self._route.route_finished:
            self._direction = 0
            self._send_direction_to_consumers()
            return
            
        # Рассчитываем правильное направление к следующей точке
        next_point = self._route.next_point()
        correct_direction = self._calculate_bearing(self._position, next_point)
        
        # Проверяем, что запрошенное направление близко к правильному
        # Допускаем отклонение до 5 градусов
        direction_diff = abs(direction - correct_direction)
        if direction_diff > 5 and direction_diff < 355:
            self._log_message(LOG_ERROR, 
                f"принудительная установка направления! Запрошенное направление {direction}, "
                f"расчётное {correct_direction}")
            # Устанавливаем правильное направление
            self._direction = correct_direction
        else:
            # Направление допустимо
            self._direction = direction
            
        self._send_direction_to_consumers()
    
    def _set_new_speed(self, speed: float):
        """ 
        Установка новой скорости с проверкой безопасности
        
        Проверяет, что запрошенная скорость не превышает ограничения
        для текущего сегмента маршрута
        """
        # Если маршрут завершен, устанавливаем скорость 0
        if self._route.route_finished:
            self._speed = 0
            self._send_speed_to_consumers()
            return
            
        # Получаем ограничение скорости для текущего сегмента
        speed_limit = self._route.calculate_speed()
        
        # Проверяем, что запрошенная скорость не превышает ограничение
        if speed > speed_limit:
            self._log_message(LOG_ERROR, 
                f"принудительная установка скорости! Запрошенная скорость {speed}, "
                f"ограничение {speed_limit}")
            # Устанавливаем допустимую скорость
            self._speed = speed_limit
        else:
            # Скорость допустима
            self._speed = speed
            
        self._send_speed_to_consumers()
    
    def _lock_cargo(self, _):
        """ 
        Блокировка грузового отсека
        
        Разрешаем блокировку в любой момент
        """
        self._send_lock_cargo_to_consumers()
    
    def _release_cargo(self, _):
        """ 
        Разблокировка грузового отсека
        
        Разрешаем только в конечной точке маршрута
        """
        if self._route.route_finished:
            self._log_message(LOG_INFO, "маршрут завершен, разрешаем выгрузку груза")
            self._send_release_cargo_to_consumers()
        else:
            self._log_message(LOG_ERROR, "попытка выгрузки груза вне конечной точки маршрута!")
    
    def _send_speed_to_consumers(self):
        """ Отправка команды скорости в сервоприводы """
        self._log_message(LOG_DEBUG, "отправляем скорость получателям")
        servos_q_name = SERVOS_QUEUE_NAME
        servos_q: Queue = self._queues_dir.get_queue(servos_q_name)

        # Отправка сообщения с допустимой скоростью
        event_speed = Event(
            source=self.event_source_name,
            destination=servos_q_name,
            operation="set_speed",
            parameters=self._speed
        )
        servos_q.put(event_speed)

    def _send_direction_to_consumers(self):
        """ Отправка команды направления в сервоприводы """
        self._log_message(LOG_DEBUG, "отправляем направление получателям")
        servos_q_name = SERVOS_QUEUE_NAME
        servos_q: Queue = self._queues_dir.get_queue(servos_q_name)

        # Отправка сообщения с допустимым направлением
        event_direction = Event(
            source=self.event_source_name,
            destination=servos_q_name,
            operation="set_direction",
            parameters=self._direction
        )
        servos_q.put(event_direction)
        
    def _send_lock_cargo_to_consumers(self):
        """ Отправка команды блокировки груза """
        self._log_message(LOG_DEBUG, "отправляем команду блокировки груза")
        cargo_q_name = CARGO_BAY_QUEUE_NAME
        cargo_q: Queue = self._queues_dir.get_queue(cargo_q_name)

        # Отправка сообщения о блокировке груза
        event_lock = Event(
            source=self.event_source_name,
            destination=cargo_q_name,
            operation="lock_cargo",
            parameters=None
        )
        cargo_q.put(event_lock)
        
    def _send_release_cargo_to_consumers(self):
        """ Отправка команды разблокировки груза """
        self._log_message(LOG_DEBUG, "отправляем команду разблокировки груза")
        cargo_q_name = CARGO_BAY_QUEUE_NAME
        cargo_q: Queue = self._queues_dir.get_queue(cargo_q_name)

        # Отправка сообщения о разблокировке груза
        event_release = Event(
            source=self.event_source_name,
            destination=cargo_q_name,
            operation="release_cargo",
            parameters=None
        )
        cargo_q.put(event_release)
        
    def _calculate_bearing(self, start, end):
        """ 
        Расчет направления (азимута) от начальной точки к конечной
        
        Args:
            start: начальная точка (GeoPoint)
            end: конечная точка (GeoPoint)
            
        Returns:
            float: направление в градусах (0-360)
        """
        delta_longitude = end.longitude - start.longitude
        x = math.sin(math.radians(delta_longitude)) * math.cos(math.radians(end.latitude))
        y = math.cos(math.radians(start.latitude)) * math.sin(math.radians(end.latitude)) - \
            math.sin(math.radians(start.latitude)) * math.cos(math.radians(end.latitude)) * \
            math.cos(math.radians(delta_longitude))
        
        initial_bearing_rad = math.atan2(x, y)
        initial_bearing_deg = math.degrees(initial_bearing_rad)
        compass_bearing = (initial_bearing_deg + 360) % 360
        
        return compass_bearing


# ============================================================================
# КОММУНИКАЦИОННЫЙ ШЛЮЗ (COMMUNICATION GATEWAY)
# ============================================================================

class CommunicationGateway(BaseCommunicationGateway):
    """ 
    Класс коммуникационного шлюза
    
    Отправляет маршрутное задание в систему управления через монитор безопасности
    """
    
    def _send_mission_to_consumers(self):
        """ 
        Отправка маршрутного задания получателям через монитор безопасности
        """
        # Создаем событие для системы управления
        self._log_message(1, 'Отправлен Евент')
        event_safety = Event(
            source=self.event_source_name,
            destination=SAFETY_BLOCK_QUEUE_NAME,
            operation="set_mission",
            parameters=self._mission
        )

        event_control = Event(
            source=self.event_source_name,
            destination=CONTROL_SYSTEM_QUEUE_NAME,
            operation="set_mission",
            parameters=self._mission
        )
        
        safety_q: Queue = self._queues_dir.get_queue(SECURITY_MONITOR_QUEUE_NAME)
        safety_q.put(event_safety)
        control_q: Queue = self._queues_dir.get_queue(SECURITY_MONITOR_QUEUE_NAME)
        control_q.put(event_control)
        
        #security_monitor_q: Queue = self._queues_dir.get_queue(SAFETY_BLOCK_QUEUE_NAME)
        #security_monitor_q.put(event)


# ============================================================================
# СИСТЕМА НАВИГАЦИИ (NAVIGATION SYSTEM)
# ============================================================================

class NavigationSystem(BaseNavigationSystem):
    """ 
    Класс навигационного блока
    
    Отправляет координаты в систему управления через монитор безопасности
    """
    
    def _send_position_to_consumers(self):
        """ 
        Отправка координат получателям через монитор безопасности
        """
        # Создаем событие для системы управления
        event_control = Event(
            source=self.event_source_name,
            destination=CONTROL_SYSTEM_QUEUE_NAME,
            operation="position_update",
            parameters=self._position
        )
        
        event_safety = Event(
            source=self.event_source_name,
            destination=SAFETY_BLOCK_QUEUE_NAME,
            operation="position_update",
            parameters=self._position
        )

        # Отправляем событие через монитор безопасности
        security_q: Queue = self._queues_dir.get_queue(SECURITY_MONITOR_QUEUE_NAME)
        security_q.put(event_safety)
        security_q.put(event_control)

# ============================================================================
# СИСТЕМА УПРАВЛЕНИЯ (CONTROL SYSTEM)
# ============================================================================

class ControlSystem(BaseControlSystem):
    """ 
    Класс системы управления
    
    Отправляет команды скорости и направления в ограничитель через монитор безопасности
    """
    
    def _send_speed_and_direction_to_consumers(self, speed: float, direction: float):
        """ 
        Отправка команд скорости и направления в ограничитель через монитор безопасности
        """
        # Создаем события для ограничителя
        speed_event = Event(
            source=self.event_source_name,
            destination=SAFETY_BLOCK_QUEUE_NAME,
            operation="set_speed",
            parameters=speed
        )
        
        direction_event = Event(
            source=self.event_source_name,
            destination=SAFETY_BLOCK_QUEUE_NAME,
            operation="set_direction",
            parameters=direction
        )
        
        # Отправляем события через монитор безопасности
        security_monitor_q: Queue = self._queues_dir.get_queue(SECURITY_MONITOR_QUEUE_NAME)
        security_monitor_q.put(speed_event)
        security_monitor_q.put(direction_event)
    
    def _release_cargo(self):
        """ 
        Отправка команды разблокировки груза в ограничитель через монитор безопасности
        """
        # Создаем событие для ограничителя
        event = Event(
            source=self.event_source_name,
            destination=SAFETY_BLOCK_QUEUE_NAME,
            operation="release_cargo",
            parameters=None
        )
        
        # Отправляем событие через монитор безопасности
        security_monitor_q: Queue = self._queues_dir.get_queue(SECURITY_MONITOR_QUEUE_NAME)
        security_monitor_q.put(event)
    
    def _lock_cargo(self):
        """ 
        Отправка команды блокировки груза в ограничитель через монитор безопасности
        """
        # Создаем событие для ограничителя
        event = Event(
            source=self.event_source_name,
            destination=SAFETY_BLOCK_QUEUE_NAME,
            operation="lock_cargo",
            parameters=None
        )
        security_monitor_q: Queue = self._queues_dir.get_queue(SECURITY_MONITOR_QUEUE_NAME)
        security_monitor_q.put(event)
    

        
class SecurityMonitor(BaseSecurityMonitor):
   
    def __init__(self, queues_dir: QueuesDirectory):
        """
        Иницилиация полити безопаснсоти по умолчанию

        Переопрделение типа переменной self__security_policies с словаря на список
        """
        super().__init__(queues_dir)
        self._security_policies = set()
        self._init_set_security_policies()
     
    
    def _init_set_security_policies(self):
        """ 
        Инициализация политик безопасности
        
        Определяет разрешенные взаимодействия между компонентами системы
        """
        # Базовые политики безопасности
        default_policies = [
            # Коммуникационный шлюз -> Система управления: установка маршрутного задания
            SecurityPolicy(
                source=COMMUNICATION_GATEWAY_QUEUE_NAME,
                destination=CONTROL_SYSTEM_QUEUE_NAME,
                operation='set_mission'),

            # Коммуникационный шлюз -> Огрначительный блок: установка маршрутного задания
            SecurityPolicy(
                source=COMMUNICATION_GATEWAY_QUEUE_NAME,
                destination=SAFETY_BLOCK_QUEUE_NAME,
                operation='set_mission'), 

            # Система управления -> Ограничитель: установка скорости
            SecurityPolicy(
                source=CONTROL_SYSTEM_QUEUE_NAME,
                destination=SAFETY_BLOCK_QUEUE_NAME,
                operation='set_speed'),
                
            # Система управления -> Ограничитель: установка направления
            SecurityPolicy(
                source=CONTROL_SYSTEM_QUEUE_NAME,
                destination=SAFETY_BLOCK_QUEUE_NAME,
                operation='set_direction'),

            # Система Навигации -> Ограничетльный блок: установка направления
            SecurityPolicy(
                source=NAVIGATION_QUEUE_NAME,
                destination=SAFETY_BLOCK_QUEUE_NAME,
                operation='position_update'),

            # Система навигации -> Блок Управления: установка направления
            SecurityPolicy(
                source=NAVIGATION_QUEUE_NAME,
                destination=CONTROL_SYSTEM_QUEUE_NAME,
                operation='position_update'),

            # Система управления -> Ограничитель: блокировка груза
            SecurityPolicy(
                source=CONTROL_SYSTEM_QUEUE_NAME,
                destination=SAFETY_BLOCK_QUEUE_NAME,
                operation='lock_cargo'),
                
            # Система управления -> Ограничитель: разблокировка груза
            SecurityPolicy(
                source=CONTROL_SYSTEM_QUEUE_NAME,
                destination=SAFETY_BLOCK_QUEUE_NAME,
                operation='release_cargo'),
                
            # Ограничитель -> Сервоприводы: установка скорости
            SecurityPolicy(
                source=SAFETY_BLOCK_QUEUE_NAME,
                destination=SERVOS_QUEUE_NAME,
                operation='set_speed'),
                
            # Ограничитель -> Сервоприводы: установка направления
            SecurityPolicy(
                source=SAFETY_BLOCK_QUEUE_NAME,
                destination=SERVOS_QUEUE_NAME,
                operation='set_direction'),
                
            # Ограничитель -> Грузовой отсек: блокировка груза
            SecurityPolicy(
                source=SAFETY_BLOCK_QUEUE_NAME,
                destination=CARGO_BAY_QUEUE_NAME,
                operation='lock_cargo'),
                
            # Ограничитель -> Грузовой отсек: разблокировка груза
            SecurityPolicy(
                source=SAFETY_BLOCK_QUEUE_NAME,
                destination=CARGO_BAY_QUEUE_NAME,
                operation='release_cargo'),
        ]
        
        self.set_security_policies(policies=default_policies)
    
    def set_security_policies(self, policies):
        """ 
        Установка новых политик безопасности
        
        Args:
            policies: список политик безопасности
        """
        self._security_policies = policies
        self._log_message(
            LOG_INFO, f"изменение политик безопасности: {policies}")
    
    def _check_event(self, event: Event):
        """ 
        Проверка входящих событий на соответствие политикам безопасности
        
        Args:
            event: проверяемое событие
            
        Returns:
            bool: True если событие разрешено, False если запрещено
        """
        self._log_message(
            LOG_DEBUG, f"проверка события {event}, по умолчанию выполнение запрещено")
        
        authorized = False
     
        # Проверяем, есть ли соответствующая политика
        for policy in self._security_policies:
            if (policy.source == event.source and 
                policy.destination == event.destination and 
                policy.operation == event.operation):
                self._log_message(
                    LOG_DEBUG, "событие разрешено политиками, выполняем")
                authorized = True
                break
                
            self._log_message(
                LOG_DEBUG, "событие разрешено политиками, выполняем")
        
        if authorized is False:
            self._log_message(LOG_ERROR, f"событие не разрешено политиками безопасности! {event}")
            
        return authorized

# %% [markdown]
# Если у вас настроена и работает СУПА, установите в True значение переменной afcs_present

# %%
afcs_present = True

# %% [markdown]
# Поменяем идентификатор машинки для этого модуля

# %%
car_id = "m4"

# %% [markdown]
# В следующем блоке измените маршрут на ваш, его можно скопировать из модуля 2.
#
# Для проверки работы систем безопасности будут активированы киберпрепятствия
#
# ```python
# control_system.enable_surprises()
# ```

# %%
# используем то же маршрутное задание, которое было в модуле 2
from time import sleep

from src.queues_dir import QueuesDirectory
from src.servos import Servos
from src.sitl import SITL
from src.cargo_bay import CargoBay
from src.mission_planner import MissionPlanner
from src.config import LOG_ERROR, LOG_INFO
from src.mission_planner_mqtt import MissionSender
from src.mission_planner import Mission
from src.sitl_mqtt import TelemetrySender
from src.system_wrapper import SystemComponentsContainer
from src.wpl_parser import WPLParser
from src.mission_type import GeoSpecificSpeedLimit


# для примера возьмём маршрут из модуля 2
# следует заменить на маршрут, требуемый по регламенту!
wpl_file = "module2.wpl"

parser = WPLParser(wpl_file)    
points = parser.parse()

# обновите скоростные ограничения для вашего маршрута!
speed_limits = [
    GeoSpecificSpeedLimit(0, 30),
    GeoSpecificSpeedLimit(1, 60),
    GeoSpecificSpeedLimit(5, 20),
]


home = points[0]
mission = Mission(home=home, waypoints=points,speed_limits=speed_limits, armed=True)

# каталог очередей для передачи сообщений между блоками
queues_dir = QueuesDirectory() 


# создание блоков передачи данных в СУПА
if afcs_present:
    mission_sender = MissionSender(
        queues_dir=queues_dir, client_id=car_id, log_level=LOG_ERROR)
    telemetry_sender = TelemetrySender(
        queues_dir=queues_dir, client_id=car_id, log_level=LOG_ERROR)

# создание основных функциональных блоков
mission_planner = MissionPlanner(
    queues_dir, afcs_present=afcs_present, mission=mission)

sitl = SITL(
    queues_dir=queues_dir, position=home,
    car_id=car_id, post_telemetry=afcs_present, log_level=LOG_ERROR)

communication_gateway = CommunicationGateway(
    queues_dir=queues_dir, log_level=LOG_ERROR)
control_system = ControlSystem(queues_dir=queues_dir, log_level=LOG_INFO)

navigation_system = NavigationSystem(
    queues_dir=queues_dir, log_level=LOG_ERROR)

servos = Servos(queues_dir=queues_dir, log_level=LOG_ERROR)
cargo_bay = CargoBay(queues_dir=queues_dir, log_level=LOG_INFO)

safety_block = SafetyBlock(queues_dir=queues_dir, log_level=LOG_INFO)

security_monitor = SecurityMonitor(queues_dir)

# сборка всех запускаемых блоков в одном "кузове"
system_components = SystemComponentsContainer(
    components=[
        mission_sender,
        telemetry_sender,
        sitl,
        mission_planner,
        navigation_system,
        servos,
        cargo_bay,
        communication_gateway,
        control_system,
        safety_block,
        security_monitor
    ] if afcs_present else [
        sitl,
        mission_planner,
        navigation_system,
        servos,
        cargo_bay,
        communication_gateway,
        control_system,
        safety_block,
        security_monitor
    ])

#################################
# АКТИВАЦИЯ КИБЕРПРЕПЯТСТВИЙ
control_system.enable_surprises()
#################################

# запуск всех блоков
system_components.start()

# ограничение поездки по времени
# в случае превышения времени выполнения ячейки на более чем 10 секунд от заданного, 
# допустимо перезапустить вычислительное ядро и повторно выполнить весь блокнот, штрафные очки за это не начисляются
# при условии, что повторный запуск закончился успешно
sleep(110)

# останавливаем все компоненты
system_components.stop()

# удалим все созданные компоненты
system_components.clean()
# Out:
# [ИНФО][QUEUES] создан каталог очередей
# [ИНФО][QUEUES] регистрируем очередь planner.mqtt
# [ИНФО][QUEUES] регистрируем очередь sitl.mqtt
# [ИНФО][QUEUES] регистрируем очередь planner
# [ИНФО][MISSION PLANNER] создана система планирования заданий
# [ИНФО][QUEUES] регистрируем очередь sitl
# [ИНФО][QUEUES] регистрируем очередь communication
# [ИНФО][QUEUES] регистрируем очередь control
# [ИНФО][CONTROL] создана система управления
# [ИНФО][QUEUES] регистрируем очередь navigation
# [ИНФО][QUEUES] регистрируем очередь servos
# [ИНФО][QUEUES] регистрируем очередь cargo
# [ИНФО][CARGO] создан компонент грузового отсека, отсек заблокирован
# [ИНФО][QUEUES] регистрируем очередь safety
# [ИНФО][SAFETY] создан ограничитель
# [ИНФО][QUEUES] регистрируем очередь security
# [ИНФО][SECURITY] создан монитор безопасности
# [ИНФО][SECURITY] изменение политик безопасности: [SecurityPolicy(source='communication', destination='control', operation='set_mission'), SecurityPolicy(source='communication', destination='safety', operation='set_mission'), SecurityPolicy(source='control', destination='safety', operation='set_speed'), SecurityPolicy(source='control', destination='safety', operation='set_direction'), SecurityPolicy(source='navigation', destination='safety', operation='position_update'), SecurityPolicy(source='navigation', destination='control', operation='position_update'), SecurityPolicy(source='control', destination='safety', operation='lock_cargo'), SecurityPolicy(source='control', destination='safety', operation='release_cargo'), SecurityPolicy(source='safety', destination='servos', operation='set_speed'), SecurityPolicy(source='safety', destination='servos', operation='set_direction'), SecurityPolicy(source='safety', destination='cargo', operation='lock_cargo'), SecurityPolicy(source='safety', destination='cargo', operation='release_cargo')]
# [ИНФО][MISSION PLANNER] старт системы планирования заданий
# [ИНФО][CARGO] старт блока грузового отсека[ИНФО][CONTROL] старт системы управления
#
# [ИНФО][MISSION PLANNER] запрошена новая задача, отправляем получателям[ИНФО][SAFETY] старт ограничителя
#
# [ИНФО][MISSION PLANNER] новая задача отправлена в коммуникационный шлюз
# [ИНФО][SECURITY] старт блока грузового отсека
# [ОШИБКА][COMMUNICATION] Отправлен Евент
# [ИНФО][CONTROL] установлена новая задача, начинаем следовать по маршруту, текущее время 19:44:48.432029
# [ИНФО][CONTROL] новая скорость 30 (была 0)
# [ИНФО][CONTROL] новое направление 251 (было 0)
# [ИНФО][CARGO] заблокировать грузовой отсек
# [ИНФО][CARGO] грузовой отсек заблокирован
# [ИНФО][SAFETY] текущие координаты: 59 56m 20.7822s N, 30 18m 56.4412s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 20.7822s N, 30 18m 56.4412s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 20.7822s N, 30 18m 56.4412s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 20.7822s N, 30 18m 56.4412s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 20.739s N, 30 18m 56.1871s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 20.7043s N, 30 18m 55.9839s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 20.6611s N, 30 18m 55.7298s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 20.6178s N, 30 18m 55.4757s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 20.5745s N, 30 18m 55.2216s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 20.5312s N, 30 18m 54.9675s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 20.4966s N, 30 18m 54.7643s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 20.4533s N, 30 18m 54.5102s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 20.4101s N, 30 18m 54.2561s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 20.3668s N, 30 18m 54.002s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 20.3235s N, 30 18m 53.7479s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 20.2803s N, 30 18m 53.4938s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 20.237s N, 30 18m 53.2398s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 20.1937s N, 30 18m 52.9857s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 20.1591s N, 30 18m 52.7824s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 20.1158s N, 30 18m 52.5283s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 20.0726s N, 30 18m 52.2742s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 20.0293s N, 30 18m 52.0201s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 19.9861s N, 30 18m 51.766s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 19.9428s N, 30 18m 51.5119s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 19.8996s N, 30 18m 51.2578s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 19.8563s N, 30 18m 51.0037s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 19.8217s N, 30 18m 50.8004s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 19.7785s N, 30 18m 50.5463s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 19.7352s N, 30 18m 50.2922s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 19.692s N, 30 18m 50.0381s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 19.6574s N, 30 18m 49.8348s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 19.6141s N, 30 18m 49.5807s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 19.5709s N, 30 18m 49.3266s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 19.5277s N, 30 18m 49.0725s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 19.4845s N, 30 18m 48.8184s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 19.4412s N, 30 18m 48.5643s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 19.4067s N, 30 18m 48.361s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 19.3634s N, 30 18m 48.1068s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 19.3202s N, 30 18m 47.8527s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 19.277s N, 30 18m 47.5986s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 19.2338s N, 30 18m 47.3445s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 19.1906s N, 30 18m 47.0903s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 19.1474s N, 30 18m 46.8362s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 19.1042s N, 30 18m 46.5821s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 19.061s N, 30 18m 46.3279s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 19.0178s N, 30 18m 46.0738s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 18.9833s N, 30 18m 45.8705s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 18.9401s N, 30 18m 45.6163s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 18.897s N, 30 18m 45.3621s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 18.8538s N, 30 18m 45.108s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 18.8107s N, 30 18m 44.8538s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 18.7676s N, 30 18m 44.5996s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 18.7244s N, 30 18m 44.3454s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новая скорость 60 (была 30)
# [ИНФО][CONTROL] новое направление 142 (было 251)[ИНФО][SAFETY] сегмент пройден
#
# [ИНФО][SAFETY] текущие координаты: 59 56m 18.6814s N, 30 18m 44.0912s E
# [ОШИБКА][SAFETY] принудительная установка направления! Запрошенное направление 142.06772965310006, расчётное 322.06772965310006
# [ИНФО][SAFETY] текущие координаты: 59 56m 18.6383s N, 30 18m 43.837s E
# [ОШИБКА][SAFETY] принудительная установка направления! Запрошенное направление 142.50959799743936, расчётное 322.50959799743936
# [ИНФО][SAFETY] текущие координаты: 59 56m 18.5954s N, 30 18m 43.5827s E
# [ОШИБКА][SAFETY] принудительная установка направления! Запрошенное направление 142.95361711789855, расчётное 322.95361711789855
# [ИНФО][CONTROL] новое направление 143 (было 142)
# [ИНФО][SAFETY] текущие координаты: 59 56m 18.5611s N, 30 18m 43.3792s E
# [ОШИБКА][SAFETY] принудительная установка направления! Запрошенное направление 143.3104950110975, расчётное 323.3104950110975
# [ИНФО][SAFETY] текущие координаты: 59 56m 18.7747s N, 30 18m 43.0526s E
# [ОШИБКА][SAFETY] принудительная установка направления! Запрошенное направление 143.3230142217734, расчётное 323.3230142217734
# [ИНФО][SAFETY] текущие координаты: 59 56m 18.9897s N, 30 18m 42.7293s E
# [ОШИБКА][SAFETY] принудительная установка направления! Запрошенное направление 143.32842113578852, расчётное 323.3284211357885
# [ИНФО][SAFETY] текущие координаты: 59 56m 19.2056s N, 30 18m 42.4086s E
# [ОШИБКА][SAFETY] принудительная установка направления! Запрошенное направление 143.32785186472404, расчётное 323.32785186472404
# [ИНФО][SAFETY] текущие координаты: 59 56m 19.4215s N, 30 18m 42.0881s E
# [ОШИБКА][SAFETY] принудительная установка направления! Запрошенное направление 143.32704387638142, расчётное 323.3270438763814
# [ИНФО][SAFETY] текущие координаты: 59 56m 19.6375s N, 30 18m 41.7676s E
# [ОШИБКА][SAFETY] принудительная установка направления! Запрошенное направление 143.32620834050522, расчётное 323.3262083405052
# [ИНФО][SAFETY] текущие координаты: 59 56m 19.8535s N, 30 18m 41.4471s E
# [ОШИБКА][SAFETY] принудительная установка направления! Запрошенное направление 143.32524524775056, расчётное 323.32524524775056
# [ИНФО][SAFETY] текущие координаты: 59 56m 20.0695s N, 30 18m 41.1266s E
# [ОШИБКА][SAFETY] принудительная установка направления! Запрошенное направление 143.32426138711634, расчётное 323.32426138711634
# [ИНФО][SAFETY] текущие координаты: 59 56m 20.2422s N, 30 18m 40.8702s E
# [ОШИБКА][SAFETY] принудительная установка направления! Запрошенное направление 143.32345838518097, расчётное 323.32345838518097
# [ИНФО][SAFETY] текущие координаты: 59 56m 20.4582s N, 30 18m 40.5496s E
# [ОШИБКА][SAFETY] принудительная установка направления! Запрошенное направление 143.32243730204254, расчётное 323.32243730204254
# [ИНФО][SAFETY] текущие координаты: 59 56m 20.6742s N, 30 18m 40.2291s E
# [ОШИБКА][SAFETY] принудительная установка направления! Запрошенное направление 143.32139658629796, расчётное 323.32139658629796
# [ИНФО][SAFETY] текущие координаты: 59 56m 20.8901s N, 30 18m 39.9086s E
# [ОШИБКА][SAFETY] принудительная установка направления! Запрошенное направление 143.3203515080653, расчётное 323.3203515080653
# [ИНФО][SAFETY] текущие координаты: 59 56m 21.0629s N, 30 18m 39.6521s E
# [ОШИБКА][SAFETY] принудительная установка направления! Запрошенное направление 143.3195025964966, расчётное 323.3195025964966
# [ИНФО][SAFETY] текущие координаты: 59 56m 21.2789s N, 30 18m 39.3316s E
# [ОШИБКА][SAFETY] принудительная установка направления! Запрошенное направление 143.31842487109964, расчётное 323.31842487109964
# [ИНФО][SAFETY] текущие координаты: 59 56m 21.4948s N, 30 18m 39.011s E
# [ОШИБКА][SAFETY] принудительная установка направления! Запрошенное направление 143.3173252717529, расчётное 323.3173252717529
# [ИНФО][SAFETY] текущие координаты: 59 56m 21.7108s N, 30 18m 38.6904s E
# [ОШИБКА][SAFETY] принудительная установка направления! Запрошенное направление 143.31619814151634, расчётное 323.31619814151634
# [ИНФО][SAFETY] текущие координаты: 59 56m 21.9267s N, 30 18m 38.3699s E
# [ОШИБКА][SAFETY] принудительная установка направления! Запрошенное направление 143.31504670838893, расчётное 323.31504670838893
# [ИНФО][SAFETY] текущие координаты: 59 56m 22.0995s N, 30 18m 38.1134s E
# [ОШИБКА][SAFETY] принудительная установка направления! Запрошенное направление 143.3141092934813, расчётное 323.3141092934813
# [ИНФО][SAFETY] текущие координаты: 59 56m 22.3154s N, 30 18m 37.7928s E
# [ОШИБКА][SAFETY] принудительная установка направления! Запрошенное направление 143.31291651213576, расчётное 323.31291651213576
# [ИНФО][SAFETY] текущие координаты: 59 56m 22.5313s N, 30 18m 37.4722s E
# [ОШИБКА][SAFETY] принудительная установка направления! Запрошенное направление 143.31169646818466, расчётное 323.31169646818466
# [ИНФО][SAFETY] текущие координаты: 59 56m 22.7473s N, 30 18m 37.1516s E
# [ОШИБКА][SAFETY] принудительная установка направления! Запрошенное направление 143.31044202949397, расчётное 323.31044202949397
# [ИНФО][SAFETY] текущие координаты: 59 56m 22.9632s N, 30 18m 36.831s E
# [ОШИБКА][SAFETY] принудительная установка направления! Запрошенное направление 143.3091274892472, расчётное 323.3091274892472
# [ИНФО][SAFETY] текущие координаты: 59 56m 23.1792s N, 30 18m 36.5103s E
# [ОШИБКА][SAFETY] принудительная установка направления! Запрошенное направление 143.3077784898266, расчётное 323.3077784898266
# [ИНФО][SAFETY] текущие координаты: 59 56m 23.3519s N, 30 18m 36.2538s E
# [ОШИБКА][SAFETY] принудительная установка направления! Запрошенное направление 143.30667571301365, расчётное 323.30667571301365
# [ИНФО][SAFETY] текущие координаты: 59 56m 23.5678s N, 30 18m 35.9332s E
# [ОШИБКА][SAFETY] принудительная установка направления! Запрошенное направление 143.3052664931941, расчётное 323.3052664931941
# [ИНФО][SAFETY] текущие координаты: 59 56m 23.7837s N, 30 18m 35.6125s E
# [ОШИБКА][SAFETY] принудительная установка направления! Запрошенное направление 143.3038183364102, расчётное 323.3038183364102
# [ИНФО][SAFETY] текущие координаты: 59 56m 23.9997s N, 30 18m 35.2919s E
# [ОШИБКА][SAFETY] принудительная установка направления! Запрошенное направление 143.30232893333243, расчётное 323.30232893333243
# [ИНФО][SAFETY] текущие координаты: 59 56m 24.2156s N, 30 18m 34.9712s E
# [ОШИБКА][SAFETY] принудительная установка направления! Запрошенное направление 143.30078761300882, расчётное 323.3007876130088
# [ИНФО][SAFETY] текущие координаты: 59 56m 24.4315s N, 30 18m 34.6505s E
# [ОШИБКА][SAFETY] принудительная установка направления! Запрошенное направление 143.29924184953938, расчётное 323.2992418495394
# [ИНФО][SAFETY] текущие координаты: 59 56m 24.6042s N, 30 18m 34.3939s E
# [ОШИБКА][SAFETY] принудительная установка направления! Запрошенное направление 143.29797543218848, расчётное 323.2979754321885
# [ИНФО][SAFETY] текущие координаты: 59 56m 24.8201s N, 30 18m 34.0732s E
# [ОШИБКА][SAFETY] принудительная установка направления! Запрошенное направление 143.29635350756394, расчётное 323.29635350756394
# [ИНФО][SAFETY] текущие координаты: 59 56m 25.036s N, 30 18m 33.7525s E
# [ОШИБКА][SAFETY] принудительная установка направления! Запрошенное направление 143.29467903178954, расчётное 323.29467903178954
# [ИНФО][SAFETY] текущие координаты: 59 56m 25.2519s N, 30 18m 33.4317s E
# [ОШИБКА][SAFETY] принудительная установка направления! Запрошенное направление 143.29293737553667, расчётное 323.29293737553667
# [ИНФО][SAFETY] текущие координаты: 59 56m 25.4678s N, 30 18m 33.111s E
# [ОШИБКА][SAFETY] принудительная установка направления! Запрошенное направление 143.29113386655922, расчётное 323.2911338665592
# [ИНФО][SAFETY] текущие координаты: 59 56m 25.6837s N, 30 18m 32.7902s E
# [ОШИБКА][SAFETY] принудительная установка направления! Запрошенное направление 143.28920365644012, расчётное 323.2892036564401
# [ИНФО][SAFETY] текущие координаты: 59 56m 25.8995s N, 30 18m 32.4695s E
# [ОШИБКА][SAFETY] принудительная установка направления! Запрошенное направление 143.28719490410623, расчётное 323.28719490410623
# [ИНФО][SAFETY] текущие координаты: 59 56m 26.1154s N, 30 18m 32.1487s E
# [ОШИБКА][SAFETY] принудительная установка направления! Запрошенное направление 143.28510109397666, расчётное 323.28510109397666
# [ИНФО][SAFETY] текущие координаты: 59 56m 26.3313s N, 30 18m 31.8279s E
# [ОШИБКА][SAFETY] принудительная установка направления! Запрошенное направление 143.2829299690282, расчётное 323.2829299690282
# [ИНФО][SAFETY] текущие координаты: 59 56m 26.504s N, 30 18m 31.5712s E
# [ОШИБКА][SAFETY] принудительная установка направления! Запрошенное направление 143.28111675309344, расчётное 323.28111675309344
# [ИНФО][SAFETY] текущие координаты: 59 56m 26.7198s N, 30 18m 31.2504s E
# [ОШИБКА][SAFETY] принудительная установка направления! Запрошенное направление 143.27885414586683, расчётное 323.27885414586683
# [ИНФО][SAFETY] текущие координаты: 59 56m 26.9357s N, 30 18m 30.9295s E
# [ОШИБКА][SAFETY] принудительная установка направления! Запрошенное направление 143.27648827233838, расчётное 323.2764882723384
# [ИНФО][SAFETY] текущие координаты: 59 56m 27.1515s N, 30 18m 30.6087s E
# [ОШИБКА][SAFETY] принудительная установка направления! Запрошенное направление 143.27398743582825, расчётное 323.27398743582825
# [ИНФО][SAFETY] текущие координаты: 59 56m 27.3674s N, 30 18m 30.2878s E
# [ОШИБКА][SAFETY] принудительная установка направления! Запрошенное направление 143.27135384169281, расчётное 323.2713538416928
# [ИНФО][SAFETY] текущие координаты: 59 56m 27.5832s N, 30 18m 29.9669s E
# [ОШИБКА][SAFETY] принудительная установка направления! Запрошенное направление 143.2685720104538, расчётное 323.2685720104538
# [ИНФО][SAFETY] текущие координаты: 59 56m 27.799s N, 30 18m 29.6459s E
# [ОШИБКА][SAFETY] принудительная установка направления! Запрошенное направление 143.2656247872365, расчётное 323.2656247872365
# [ИНФО][SAFETY] текущие координаты: 59 56m 28.0148s N, 30 18m 29.325s E
# [ОШИБКА][SAFETY] принудительная установка направления! Запрошенное направление 143.26249086266455, расчётное 323.26249086266455
# [ИНФО][SAFETY] текущие координаты: 59 56m 28.2306s N, 30 18m 29.004s E
# [ОШИБКА][SAFETY] принудительная установка направления! Запрошенное направление 143.25914458712725, расчётное 323.25914458712725
# [ИНФО][SAFETY] текущие координаты: 59 56m 28.4464s N, 30 18m 28.683s E
# [ОШИБКА][SAFETY] принудительная установка направления! Запрошенное направление 143.25555463354618, расчётное 323.2555546335462
# [ИНФО][SAFETY] текущие координаты: 59 56m 28.6622s N, 30 18m 28.362s E
# [ОШИБКА][SAFETY] принудительная установка направления! Запрошенное направление 143.25145947542342, расчётное 323.2514594754234
# [ИНФО][SAFETY] текущие координаты: 59 56m 28.878s N, 30 18m 28.041s E
# [ОШИБКА][SAFETY] принудительная установка направления! Запрошенное направление 143.24698291618574, расчётное 323.24698291618574
# [ИНФО][SAFETY] текущие координаты: 59 56m 29.0507s N, 30 18m 27.7842s E
# [ОШИБКА][SAFETY] принудительная установка направления! Запрошенное направление 143.24309863059494, расчётное 323.24309863059494
# [ИНФО][SAFETY] текущие координаты: 59 56m 29.2664s N, 30 18m 27.4631s E
# [ОШИБКА][SAFETY] принудительная установка направления! Запрошенное направление 143.23779190305942, расчётное 323.2377919030594
# [ИНФО][SAFETY] текущие координаты: 59 56m 29.4822s N, 30 18m 27.142s E
# [ОШИБКА][SAFETY] принудительная установка направления! Запрошенное направление 143.2318571313756, расчётное 323.2318571313756
# [ИНФО][SAFETY] текущие координаты: 59 56m 29.6979s N, 30 18m 26.8208s E
# [ОШИБКА][SAFETY] принудительная установка направления! Запрошенное направление 143.2255513085895, расчётное 323.2255513085895
# [ИНФО][SAFETY] текущие координаты: 59 56m 29.9136s N, 30 18m 26.4996s E
# [ОШИБКА][SAFETY] принудительная установка направления! Запрошенное направление 143.21837003530516, расчётное 323.21837003530516
# [ИНФО][SAFETY] текущие координаты: 59 56m 30.0862s N, 30 18m 26.2426s E
# [ОШИБКА][SAFETY] принудительная установка направления! Запрошенное направление 143.21188229307023, расчётное 323.21188229307023
# [ИНФО][SAFETY] текущие координаты: 59 56m 30.3019s N, 30 18m 25.9214s E
# [ОШИБКА][SAFETY] принудительная установка направления! Запрошенное направление 143.2015233176213, расчётное 323.2015233176213
# [ИНФО][SAFETY] текущие координаты: 59 56m 30.5176s N, 30 18m 25.6s E
# [ОШИБКА][SAFETY] принудительная установка направления! Запрошенное направление 143.18985269331284, расчётное 323.18985269331284
# [ИНФО][SAFETY] текущие координаты: 59 56m 30.7332s N, 30 18m 25.2786s E
# [ОШИБКА][SAFETY] принудительная установка направления! Запрошенное направление 143.1744188969178, расчётное 323.1744188969178
# [ИНФО][SAFETY] текущие координаты: 59 56m 30.9488s N, 30 18m 24.9571s E
# [ОШИБКА][SAFETY] принудительная установка направления! Запрошенное направление 143.15307664806437, расчётное 323.15307664806437
# [ИНФО][SAFETY] текущие координаты: 59 56m 31.1644s N, 30 18m 24.6356s E
# [ОШИБКА][SAFETY] принудительная установка направления! Запрошенное направление 143.11915023247695, расчётное 323.11915023247695
# [ИНФО][SAFETY] текущие координаты: 59 56m 31.3369s N, 30 18m 24.3782s E
# [ОШИБКА][SAFETY] принудительная установка направления! Запрошенное направление 143.07003121219293, расчётное 323.07003121219293
# [ИНФО][CONTROL] новое направление 142 (было 143)
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 56m 31.5524s N, 30 18m 24.0565s E[ИНФО][CONTROL] новая скорость 160 (была 60)
#
# [ОШИБКА][SAFETY] принудительная установка направления! Запрошенное направление 142.8409864342675, расчётное 322.8409864342675[ИНФО][CONTROL] новое направление 231 (было 142)
#
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][CONTROL] новое направление 228 (было 231)[ОШИБКА][SAFETY] принудительная установка скорости! Запрошенная скорость 160, ограничение 60
#
# [ИНФО][SAFETY] текущие координаты: 59 56m 31.7679s N, 30 18m 23.7347s E
# [ИНФО][CONTROL] новое направление 226 (было 228)[ОШИБКА][SAFETY] принудительная установка скорости! Запрошенная скорость 160, ограничение 60
#
# [ИНФО][SAFETY] текущие координаты: 59 56m 31.9833s N, 30 18m 23.4126s E
# [ИНФО][CONTROL] новое направление 223 (было 226)
# [ОШИБКА][SAFETY] принудительная установка скорости! Запрошенная скорость 160, ограничение 60
# [ИНФО][SAFETY] текущие координаты: 59 56m 32.1985s N, 30 18m 23.0901s E
# [ОШИБКА][SAFETY] принудительная установка скорости! Запрошенная скорость 160, ограничение 60
# [ИНФО][SAFETY] текущие координаты: 59 56m 32.4131s N, 30 18m 22.7659s E
# [ОШИБКА][SAFETY] принудительная установка скорости! Запрошенная скорость 160, ограничение 60
# [ИНФО][SAFETY] текущие координаты: 59 56m 32.2449s N, 30 18m 22.3469s E
# [ОШИБКА][SAFETY] принудительная установка скорости! Запрошенная скорость 160, ограничение 60
# [ИНФО][SAFETY] текущие координаты: 59 56m 32.0676s N, 30 18m 21.943s E
# [ОШИБКА][SAFETY] принудительная установка скорости! Запрошенная скорость 160, ограничение 60
# [ИНФО][SAFETY] текущие координаты: 59 56m 31.8734s N, 30 18m 21.5711s E
# [ОШИБКА][SAFETY] принудительная установка скорости! Запрошенная скорость 160, ограничение 60
# [ИНФО][SAFETY] текущие координаты: 59 56m 31.678s N, 30 18m 21.2019s E
# [ОШИБКА][SAFETY] принудительная установка скорости! Запрошенная скорость 160, ограничение 60
# [ИНФО][SAFETY] текущие координаты: 59 56m 31.4819s N, 30 18m 20.834s E
# [ОШИБКА][SAFETY] принудительная установка скорости! Запрошенная скорость 160, ограничение 60
# [ИНФО][SAFETY] текущие координаты: 59 56m 31.2858s N, 30 18m 20.4664s E
# [ОШИБКА][SAFETY] принудительная установка скорости! Запрошенная скорость 160, ограничение 60
# [ИНФО][SAFETY] текущие координаты: 59 56m 31.0896s N, 30 18m 20.0987s E
# [ОШИБКА][SAFETY] принудительная установка скорости! Запрошенная скорость 160, ограничение 60
# [ИНФО][SAFETY] текущие координаты: 59 56m 30.8934s N, 30 18m 19.7311s E
# [ОШИБКА][SAFETY] принудительная установка скорости! Запрошенная скорость 160, ограничение 60
# [ИНФО][SAFETY] текущие координаты: 59 56m 30.6972s N, 30 18m 19.3635s E
# [ОШИБКА][SAFETY] принудительная установка скорости! Запрошенная скорость 160, ограничение 60
# [ИНФО][SAFETY] текущие координаты: 59 56m 30.5403s N, 30 18m 19.0694s E
# [ОШИБКА][SAFETY] принудительная установка скорости! Запрошенная скорость 160, ограничение 60
# [ИНФО][SAFETY] текущие координаты: 59 56m 30.3441s N, 30 18m 18.7017s E
# [ОШИБКА][SAFETY] принудительная установка скорости! Запрошенная скорость 160, ограничение 60
# [ИНФО][SAFETY] текущие координаты: 59 56m 30.148s N, 30 18m 18.334s E
# [ОШИБКА][SAFETY] принудительная установка скорости! Запрошенная скорость 160, ограничение 60
# [ИНФО][SAFETY] текущие координаты: 59 56m 29.9518s N, 30 18m 17.9663s E
# [ОШИБКА][SAFETY] принудительная установка скорости! Запрошенная скорость 160, ограничение 60
# [ИНФО][SAFETY] текущие координаты: 59 56m 29.7557s N, 30 18m 17.5985s E
# [ОШИБКА][SAFETY] принудительная установка скорости! Запрошенная скорость 160, ограничение 60
# [ИНФО][SAFETY] текущие координаты: 59 56m 29.5596s N, 30 18m 17.2308s E
# [ОШИБКА][SAFETY] принудительная установка скорости! Запрошенная скорость 160, ограничение 60
# [ИНФО][SAFETY] текущие координаты: 59 56m 29.3635s N, 30 18m 16.8629s E
# [ОШИБКА][SAFETY] принудительная установка скорости! Запрошенная скорость 160, ограничение 60
# [ИНФО][SAFETY] текущие координаты: 59 56m 29.1675s N, 30 18m 16.495s E
# [ОШИБКА][SAFETY] принудительная установка скорости! Запрошенная скорость 160, ограничение 60
# [ИНФО][SAFETY] текущие координаты: 59 56m 28.9714s N, 30 18m 16.1271s E
# [ОШИБКА][SAFETY] принудительная установка скорости! Запрошенная скорость 160, ограничение 60
# [ИНФО][SAFETY] текущие координаты: 59 56m 28.7755s N, 30 18m 15.7591s E
# [ОШИБКА][SAFETY] принудительная установка скорости! Запрошенная скорость 160, ограничение 60
# [ИНФО][SAFETY] текущие координаты: 59 56m 28.5795s N, 30 18m 15.391s E
# [ОШИБКА][SAFETY] принудительная установка скорости! Запрошенная скорость 160, ограничение 60
# [ИНФО][SAFETY] текущие координаты: 59 56m 28.3836s N, 30 18m 15.0228s E
# [ОШИБКА][SAFETY] принудительная установка скорости! Запрошенная скорость 160, ограничение 60
# [ИНФО][SAFETY] текущие координаты: 59 56m 28.1877s N, 30 18m 14.6545s E
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новая скорость 60 (была 160)
# [ИНФО][CONTROL] новое направление 231 (было 223)
# [ОШИБКА][SAFETY] попытка выгрузки груза вне конечной точки маршрута!
# [ИНФО][SAFETY] текущие координаты: 59 56m 28.031s N, 30 18m 14.3599s E
# [ИНФО][CONTROL] новое направление 232 (было 231)
# [ИНФО][SAFETY] текущие координаты: 59 56m 27.8352s N, 30 18m 13.9915s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 27.6395s N, 30 18m 13.6228s E
# [ИНФО][CONTROL] новое направление 233 (было 232)
# [ИНФО][SAFETY] текущие координаты: 59 56m 27.4441s N, 30 18m 13.2536s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 27.2766s N, 30 18m 12.8334s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 27.111s N, 30 18m 12.4101s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 26.9478s N, 30 18m 11.9833s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 26.7872s N, 30 18m 11.5525s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 26.6278s N, 30 18m 11.12s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 26.4687s N, 30 18m 10.687s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 26.3097s N, 30 18m 10.2538s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 26.1827s N, 30 18m 9.90707s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 26.024s N, 30 18m 9.47362s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 25.8652s N, 30 18m 9.04008s E
# [ИНФО][CONTROL] новое направление 234 (было 233)
# [ИНФО][SAFETY] текущие координаты: 59 56m 25.7067s N, 30 18m 8.60635s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 25.5482s N, 30 18m 8.17251s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новое направление 328 (было 234)
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 56m 25.3898s N, 30 18m 7.73849s E
# [ИНФО][CONTROL] новое направление 332 (было 328)
# [ИНФО][SAFETY] текущие координаты: 59 56m 25.2316s N, 30 18m 7.30424s E
# [ИНФО][CONTROL] новое направление 336 (было 332)
# [ИНФО][SAFETY] текущие координаты: 59 56m 25.0737s N, 30 18m 6.86947s E
# [ИНФО][CONTROL] новое направление 337 (было 336)
# [ИНФО][SAFETY] текущие координаты: 59 56m 25.3027s N, 30 18m 6.58722s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 25.5433s N, 30 18m 6.34672s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 25.7909s N, 30 18m 6.1356s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 26.0395s N, 30 18m 5.92964s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 26.2388s N, 30 18m 5.76675s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 26.488s N, 30 18m 5.56315s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 26.7373s N, 30 18m 5.36023s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 26.9866s N, 30 18m 5.1576s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 27.236s N, 30 18m 4.95504s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 27.4355s N, 30 18m 4.79306s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 27.6848s N, 30 18m 4.5906s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 27.9342s N, 30 18m 4.38812s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 28.1836s N, 30 18m 4.18559s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новая скорость 20 (была 60)
# [ИНФО][CONTROL] новое направление 244 (было 337)
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 56m 28.383s N, 30 18m 4.02351s E
# [ИНФО][CONTROL] новое направление 227 (было 244)
# [ИНФО][CONTROL] новое направление 213 (было 227)
# [ИНФО][SAFETY] текущие координаты: 59 56m 28.6324s N, 30 18m 3.82078s E
# [ИНФО][CONTROL] новое направление 211 (было 213)
# [ИНФО][SAFETY] текущие координаты: 59 56m 28.8815s N, 30 18m 3.61699s E
# [ИНФО][CONTROL] новое направление 208 (было 211)
# [ИНФО][SAFETY] текущие координаты: 59 56m 28.8432s N, 30 18m 3.45513s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 28.8127s N, 30 18m 3.32565s E
# [ИНФО][CONTROL] новое направление 206 (было 208)
# [ИНФО][SAFETY] текущие координаты: 59 56m 28.7524s N, 30 18m 3.19301s E
# [ИНФО][CONTROL] новое направление 205 (было 206)
# [ИНФО][SAFETY] текущие координаты: 59 56m 28.6779s N, 30 18m 3.09339s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 28.5991s N, 30 18m 3.00771s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 28.5188s N, 30 18m 2.92769s E
# [ИНФО][CONTROL] новое направление 204 (было 205)
# [ИНФО][SAFETY] текущие координаты: 59 56m 28.4379s N, 30 18m 2.85012s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 28.3568s N, 30 18m 2.77368s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 28.2755s N, 30 18m 2.69779s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 28.1941s N, 30 18m 2.62221s E
# [ИНФО][CONTROL] маршрут пройден, текущее время 19:46:24.529248
# [ИНФО][CONTROL] новая скорость 0.0 (была 20)
# [ИНФО][CONTROL] новое направление 0 (было 204)
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут завершен, разрешаем выгрузку груза
# [ИНФО][SAFETY] текущие координаты: 59 56m 28.129s N, 30 18m 2.56189s E
# [ИНФО][CARGO] выгрузка
# [ИНФО][CARGO] груз оставлен
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден

# %% [markdown]
# Убедитесь, что
# 1. ваша машинка успешно прошла весь заданный маршрут
# 2. не превысила ограничения скорости
# 3. успешно доставила груз
#
# Если всё так - поздравляем, вы справились с заданием! Обязательно зафиксируйте все изменения в репозитории!

# %% [markdown]
# Мы будем признательны за обратную связь - любые комментарии, которые вы можете дать по итогам выполнения этого задания.
#
# Например,
#
# - было ли задание понятным по шкале 1..10 (1 - ничего не понятно, 10 - вопросов вообще не было, всё понятно)?
# - было ли задание интересным по шкале 1..10 (1 - скука смертная, 10 - лучшее, что вам пока встречалось на олимпиадах)?
# - что бы вы предложили изменить, чтобы сделает его более интересным?
# - по шкале 1..10 насколько сложным оно было для вас?
# - что было самым трудным в задании?
#
# Авторы наиболее развёрнутых и интересных комментариев получат особенный приз от Лаборатории Касперского!

# %% [markdown]
# Дополнительная информация о кибериммунной разработке
# - https://os.kaspersky.ru/cyber-immune-development/
# - https://github.com/sergey-sobolev/cyberimmune-systems/wiki/%D0%9A%D0%B8%D0%B1%D0%B5%D1%80%D0%B8%D0%BC%D0%BC%D1%83%D0%BD%D0%B8%D1%82%D0%B5%D1%82
# - канал в телеграм: https://t.me/learning_cyberimmunity
